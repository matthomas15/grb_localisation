# %%
from modules.gridSearch.gridSearch import *
# from gridSearch.skygrid import *

# %%
# load skygrid

phi, theta = np.load('modules/gridSearch/sphericalGrids/1pt_perDeg_uniform_skygrid.npy')

square_deg_per_point = 41253 / len(phi)

cx = np.sin(theta) * np.cos(phi)
cy = np.sin( theta ) * np.sin( phi )
cz = np.cos( theta )

coords = np.array([cx, cy, cz])

# %%
# set satellite & GRB params

sat_xyz = np.array([ 
                    # [0, 6371, 0],
                    # [0, 6371, 0],
                    [-6371, 0, 0],
                    [0, -6371, 0]
])

sat_pointing_coords = np.array([ 
                            # [np.pi, np.pi/2],
                            # [np.pi + 0.3, np.pi/2 - 0.2],
                            [np.pi/2 - 0.3, np.pi - 0.2],
                            [np.pi/2 + 0.3, np.pi + 0.3]
                          ])


sat_pointings = np.array([s2c(*sat_pointing_coords[i]) for i in range(len(sat_pointing_coords))])

grb_coords = np.pi/2 + 0.6, np.pi + 1 # theta, phi
grb_vector = s2c(*grb_coords)
grb_flux = 1000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 18
#       3 sat_xyz = np.array([
#       4                     # [0, 6371, 0],
#       5                     # [0, 6371, 0],
#       6                     [-6371, 0, 0],
#       7                     [0, -6371, 0]
#       8 ])
#      10 sat_pointing_coords = np.array([
#      11                             # [np.pi, np.pi/2],
#      12                             # [np.pi + 0.3, np.pi/2 - 0.2],
#      13                             [np.pi/2 - 0.3, np.pi - 0.2],
#      14                             [np.pi/2 + 0.3, np.pi + 0.3]
#      15                           ])
# ---> 18 sat_pointings = np.array([s2c(*sat_pointing_coords[i]) for i in range(len(sat_pointing_coords))])
#      20 grb_coords = np.pi/2 + 0.6, np.pi + 1 # theta, phi
#      21 grb_vector = s2c(*grb_coords)
#
# Cell In[7], line 18, in <listcomp>(.0)
#       3 sat_xyz = np.array([
#       4                     # [0, 6371, 0],
#       5                     # [0, 6371, 0],
#       6                     [-6371, 0, 0],
#       7                     [0, -6371, 0]
#       8 ])
#      10 sat_pointing_coords = np.array([
#      11                             # [np.pi, np.pi/2],
#      12                             # [np.pi + 0.3, np.pi/2 - 0.2],
#      13                             [np.pi/2 - 0.3, np.pi - 0.2],
#      14                             [np.pi/2 + 0.3, np.pi + 0.3]
#      15                           ])
# ---> 18 sat_pointings = np.array([s2c(*sat_pointing_coords[i]) for i in range(len(sat_pointing_coords))])
#      20 grb_coords = np.pi/2 + 0.6, np.pi + 1 # theta, phi
#      21 grb_vector = s2c(*grb_coords)
#
# NameError: name 's2c' is not defined

# %%
# Demonstrate both methods working side by side (no FOV)

c0 = logLike_timeDifference(sat_xyz, grb_vector)
c0 = (c0 - np.amin(c0) < 2.3).astype('int')

c1 = logLike_fluxRatio(sat_pointings, grb_vector, grb_flux)
c1 = (c1 - np.amin(c1) < 2.3).astype('int')

plt.figure(figsize = (10,5), dpi = 150)
plt.scatter(phi, theta, s = 1, c = c0 + c1)
plt.colorbar()

plt.scatter(*sat_pointing_coords.T[::-1], marker = 'x', color = 'g')
plt.scatter(*grb_coords[::-1], color = 'r', marker = 'x')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Demonstrate both methods working side by side (no FOV)
# ----> 3 c0 = logLike_timeDifference(sat_xyz, grb_vector)
#       4 c0 = (c0 - np.amin(c0) < 2.3).astype('int')
#       6 c1 = logLike_fluxRatio(sat_pointings, grb_vector, grb_flux)
#
# NameError: name 'logLike_timeDifference' is not defined

# %%
# both methods in one function

loc, chisq = estimate_localisation(sat_xyz, sat_pointings, grb_vector, grb_flux, area_element = square_deg_per_point)

plt.figure(figsize = (10,5), dpi = 150)
plt.scatter(phi, theta, s = 1, c = chisq < 2.3)
plt.colorbar()
# plt.scatter(*grb_coords[::-1], color = 'r', marker = 'x')
plt.show()

# %%
# profiling

import time

tstart = time.time()
trials = 1_000

for j in range(trials):

    chisq =  estimate_localisation(sat_xyz, sat_pointings, grb_vector, grb_flux, area_element = square_deg_per_point)

tend = time.time()

runtime_per_loop = (tend-tstart)/trials

print(f'Average runtime per iteration = {runtime_per_loop / 1e-3} ms\n\n')

# %load_ext line_profiler

# %lprun -f estimate_localisation estimate_localisation(sat_xyz, sat_pointings, grb_vector, grb_flux, area_element = square_deg_per_point)
# Out:
# Average runtime per iteration = 0.8668069839477539 ms
#
#
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# Timer unit: 1e-09 s
#
# Total time: 0.001556 s
# File: /var/folders/m3/rdjzfhq93lv52ybt6y7584xm0000gn/T/ipykernel_89214/2398545704.py
# Function: estimate_localisation at line 126
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    126                                           def estimate_localisation(sat_xyz, sat_pointings, grb_vector, grb_flux, area_element):
#    127                                               '''
#    128                                               Compute the localisation region for a set of satellites
#    129
#    130                                               >>> IT IS ASSUMED ALL SATELLITES PASSED TO THIS FUNCTION DETECT THE GRB <<<
#    131
#    132                                               If the above is not true, FOV logic will break down
#    133                                               '''
#    134
#    135         1     800000.0 800000.0     51.4      Ctime = logLike_timeDifference(sat_xyz, grb_vector)
#    136         1     383000.0 383000.0     24.6      Cflux = logLike_fluxRatio(sat_pointings, grb_vector, grb_flux)
#    137         1      16000.0  16000.0      1.0      combined_chisq = Ctime + Cflux
#    138
#    139                                               # account for FOV of each satellite (presume t)
#    140
#    141         1       7000.0   7000.0      0.4      FOV_limit = np.cos( np.radians( 90 ) ) # 90 degree FOV limitation
#    142
#    143         1     130000.0 130000.0      8.4      cosTheta = np.dot(sat_pointings, coords)
#    144         1      64000.0  64000.0      4.1      cosTheta[cosTheta < FOV_limit] = np.inf
#    145         1      41000.0  41000.0      2.6      cosTheta = np.sum(cosTheta, axis = 0)
#    146         1      43000.0  43000.0      2.8      combined_chisq[ np.isinf(cosTheta) ] = np.inf
#    147
#    148                                               # Account for Earth occultation
#    149
#    150                                               ''' TODO '''
#    151
#    152                                               # Compute results
#    153
#    154         1      36000.0  36000.0      2.3      combined_chisq = combined_chisq - np.amin(combined_chisq)
#    155         1      36000.0  36000.0      2.3      loc68 = np.sum(combined_chisq < 2.3) * area_element
#    156
#    157         1          0.0      0.0      0.0      return loc68, combined_chisq
